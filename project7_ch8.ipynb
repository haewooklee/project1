# %%
#시계열분석 = supervise learning

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
today = datetime.now()

# %%
today.microsecond
# Out:
# 576649

# %%
today.hour
# Out:
# 20

# %%
today + timedelta(days = 10) #weeks = 3 , days = 30, 
#days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0
# Out:
# datetime.datetime(2024, 10, 3, 20, 55, 4, 576649)

# %%
data = pd.DataFrame({'date': ['09/23/2024','09/2/2024','10/23/2024'], 'value' : [10,11,12]})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      object
#  1   value   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
#날짜들이 아직 object라서 날짜로 인식되지못함
#그래서 바꿔주자

data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      datetime64[ns]
#  1   value   3 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 180.0 bytes

# %%
#리스트에서 셀 하나만 가져와서 (loc사용하기) 날짜를 세분화해서 불러오기
data['date'].loc[1].day
# Out:
# 2

# %%
data = pd.DataFrame({'date': ['09-23-2024 10:22:12','09-2-2024 10:52:22','10-23-2024 12:26:32'], 'value' : [10,11,12]})

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      datetime64[ns]
#  1   value   3 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 180.0 bytes

# %%
data = pd.DataFrame({'date': ['10-11-11','10-11-12','12-11-11'], 'value' : [10,11,12]})

# %%
pd.to_datetime(data['date'], format = '%y-%m-%d')
# Out:
# 0   2010-11-11
# 1   2010-11-12
# 2   2012-11-11
# Name: date, dtype: datetime64[ns]

# %%
pip install xlrd
# Out:
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 262.6 kB/s eta 0:00:01
#    -------------------------------------- - 92.2/96.5 kB 585.1 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 616.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_excel(r"C:\Users\HWLEE\Desktop\study\ch8-강의자료및코드\ch08\code\Superstore.xls")

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data = data[['Order Date','Ship Date','Sales','Profit']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  9994 non-null   datetime64[ns]
#  1   Ship Date   9994 non-null   datetime64[ns]
#  2   Sales       9994 non-null   float64
#  3   Profit      9994 non-null   float64
# dtypes: datetime64[ns](2), float64(2)
# memory usage: 312.4 KB

# %%
data2.loc[:,'gap'] = data2['Ship Date'] - data2['Order Date']
# Out:
# C:\Users\HWLEE\AppData\Local\Temp\ipykernel_29188\2894200704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['gap'] = data2['Ship Date'] - data2['Order Date']

# %%
data['gap'] = data['Ship Date'] - data['Order Date']

# %%
data
# Out:
#      Order Date  Ship Date     Sales    Profit    gap
# 0    2016-11-08 2016-11-11  261.9600   41.9136 3 days
# 1    2016-11-08 2016-11-11  731.9400  219.5820 3 days
# 2    2016-06-12 2016-06-16   14.6200    6.8714 4 days
# 3    2015-10-11 2015-10-18  957.5775 -383.0310 7 days
# 4    2015-10-11 2015-10-18   22.3680    2.5164 7 days
# ...         ...        ...       ...       ...    ...
# 9989 2014-01-21 2014-01-23   25.2480    4.1028 2 days
# 9990 2017-02-26 2017-03-03   91.9600   15.6332 5 days
# 9991 2017-02-26 2017-03-03  258.5760   19.3932 5 days
# 9992 2017-02-26 2017-03-03   29.6000   13.3200 5 days
# 9993 2017-05-04 2017-05-09  243.1600   72.9480 5 days
#
# [9994 rows x 5 columns]

# %%
#매출을 예측해보기 위해 리니어 리그레션을 써보자

from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X = data[['Profit','gap']]
y = data['Sales']

# %%
X
# Out:
#         Profit    gap
# 0      41.9136 3 days
# 1     219.5820 3 days
# 2       6.8714 4 days
# 3    -383.0310 7 days
# 4       2.5164 7 days
# ...        ...    ...
# 9989    4.1028 2 days
# 9990   15.6332 5 days
# 9991   19.3932 5 days
# 9992   13.3200 5 days
# 9993   72.9480 5 days
#
# [9994 rows x 2 columns]

# %%
model = LinearRegression()

# %%
#model.fit(X,y) gap 이 datedelta라서 실행하면 에러남

X['gap'] = X['gap'].apply(lambda x: x.days)
# Out:
# C:\Users\HWLEE\AppData\Local\Temp\ipykernel_29188\2847284816.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['gap'] = X['gap'].apply(lambda x: x.days)

# %%
X
# Out:
#         Profit  gap
# 0      41.9136    3
# 1     219.5820    3
# 2       6.8714    4
# 3    -383.0310    7
# 4       2.5164    7
# ...        ...  ...
# 9989    4.1028    2
# 9990   15.6332    5
# 9991   19.3932    5
# 9992   13.3200    5
# 9993   72.9480    5
#
# [9994 rows x 2 columns]

# %% [markdown]
# model.fit(X,y)

# %%
model.predict(X)
# Out:
# array([248.5051552 , 474.93985046, 202.01637137, ..., 216.14692021,
#        208.40675263, 284.40140338])

# %%
data.drop('gap',axis =1,inplace = True)

# %%
data
# Out:
#      Order Date  Ship Date     Sales    Profit
# 0    2016-11-08 2016-11-11  261.9600   41.9136
# 1    2016-11-08 2016-11-11  731.9400  219.5820
# 2    2016-06-12 2016-06-16   14.6200    6.8714
# 3    2015-10-11 2015-10-18  957.5775 -383.0310
# 4    2015-10-11 2015-10-18   22.3680    2.5164
# ...         ...        ...       ...       ...
# 9989 2014-01-21 2014-01-23   25.2480    4.1028
# 9990 2017-02-26 2017-03-03   91.9600   15.6332
# 9991 2017-02-26 2017-03-03  258.5760   19.3932
# 9992 2017-02-26 2017-03-03   29.6000   13.3200
# 9993 2017-05-04 2017-05-09  243.1600   72.9480
#
# [9994 rows x 4 columns]

# %%
#date를 timestamp까지 나타내기위함

pd.to_numeric(data['Order Date'])/10**9
# Out:
# 0       1.478563e+09
# 1       1.478563e+09
# 2       1.465690e+09
# 3       1.444522e+09
# 4       1.444522e+09
#             ...
# 9989    1.390262e+09
# 9990    1.488067e+09
# 9991    1.488067e+09
# 9992    1.488067e+09
# 9993    1.493856e+09
# Name: Order Date, Length: 9994, dtype: float64

# %%
pd.set_option('display.float_format', lambda x : '%.0f' %x)

# %%
data['Order Date'] = pd.to_numeric(data['Order Date'])/10**9
data['Ship Date'] = pd.to_numeric(data['Ship Date'])/10**9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  9994 non-null   float64
#  1   Ship Date   9994 non-null   float64
#  2   Sales       9994 non-null   float64
#  3   Profit      9994 non-null   float64
# dtypes: float64(4)
# memory usage: 312.4 KB

# %%
data = pd.read_excel(r"C:\Users\HWLEE\Desktop\study\ch8-강의자료및코드\ch08\code\Superstore.xls")

# %%
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
data = data[['Order Date','Ship Date','Sales','Profit']]

# %%
pd.set_option('display.float_format', lambda x : '%.0f' %x)

# %%
data['Order Date'] = pd.to_numeric(data['Order Date'])/10**9
data['Ship Date'] = pd.to_numeric(data['Ship Date'])/10**9
# Out:
# C:\Users\HWLEE\AppData\Local\Temp\ipykernel_29188\768145660.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Order Date'] = pd.to_numeric(data['Order Date'])/10**9
# C:\Users\HWLEE\AppData\Local\Temp\ipykernel_29188\768145660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Ship Date'] = pd.to_numeric(data['Ship Date'])/10**9

# %%
data
# Out:
#       Order Date  Ship Date  Sales  Profit
# 0     1478563200 1478822400    262      42
# 1     1478563200 1478822400    732     220
# 2     1465689600 1466035200     15       7
# 3     1444521600 1445126400    958    -383
# 4     1444521600 1445126400     22       3
# ...          ...        ...    ...     ...
# 9989  1390262400 1390435200     25       4
# 9990  1488067200 1488499200     92      16
# 9991  1488067200 1488499200    259      19
# 9992  1488067200 1488499200     30      13
# 9993  1493856000 1494288000    243      73
#
# [9994 rows x 4 columns]

# %%
data['gap'] = data['Ship Date'] - data['Order Date']
# Out:
# C:\Users\HWLEE\AppData\Local\Temp\ipykernel_29188\2581058704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gap'] = data['Ship Date'] - data['Order Date']

# %%
data
# Out:
#       Order Date  Ship Date  Sales  Profit    gap
# 0     1478563200 1478822400    262      42 259200
# 1     1478563200 1478822400    732     220 259200
# 2     1465689600 1466035200     15       7 345600
# 3     1444521600 1445126400    958    -383 604800
# 4     1444521600 1445126400     22       3 604800
# ...          ...        ...    ...     ...    ...
# 9989  1390262400 1390435200     25       4 172800
# 9990  1488067200 1488499200     92      16 432000
# 9991  1488067200 1488499200    259      19 432000
# 9992  1488067200 1488499200     30      13 432000
# 9993  1493856000 1494288000    243      73 432000
#
# [9994 rows x 5 columns]

# %%
X = data[['Profit','gap']]
y = data['Sales']

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()
